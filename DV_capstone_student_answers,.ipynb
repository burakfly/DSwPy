# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df = pd.read_csv("store_sharing.csv")
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
# season
plt.figure(figsize=(6,3))
sns.countplot(x=df.season, data=df)
plt.show()

# %%
# is_holiday
sns.countplot(x=df.is_holiday, data=df)
plt.show()

# %%
# is_weekend
sns.countplot(x=df.is_weekend, data=df)
plt.show()

# %%
# weather_code
sns.countplot(x=df.weather_code, data=df)
plt.show()

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"], format="%Y%m%d%w%H")

# %%
df.head(5)
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
df.sample()
# Out:
#                      cnt    t1    t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-12-10 05:00:00  107  11.5  11.5  69.5        19.5           3.0
#
#                      is_holiday  is_weekend  season year_month
# timestamp
# 2015-12-10 05:00:00         0.0         0.0     3.0    2015-12

# %%
df["year_month"] = df.index.strftime('%Y-%m')
df["year"] = df.index.strftime("%Y")
df["month"] = df.index.month
df["day_of_month"] = df.index.day
df["day_of_week"] = df.index.day_of_week
df["hour"] = df.index.hour

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4            6     0
# 2015-01-04 01:00:00             4            6     1
# 2015-01-04 02:00:00             4            6     2
# 2015-01-04 03:00:00             4            6     3
# 2015-01-04 04:00:00             4            6     4

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
# for all variables 
plt.figure(figsize=(10,6))
ax = sns.heatmap(data=df.corr(), cmap="coolwarm", annot=True)
plt.show()

# %%
# for the target variable
plt.figure(figsize=(2,8))
ax = sns.heatmap(data=df.corr()[["cnt"]].sort_values(by="cnt", ascending=False), cmap="coolwarm", annot=True)
plt.show()

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
#with pandas
plt.figure(figsize=(12,6))
df.corr()["cnt"].sort_values().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df.sample()
# Out:
#                      cnt   t1   t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-01-21 21:00:00  666  3.0  2.0  81.0         6.0           4.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-21 21:00:00         0.0         0.0     3.0    2015-01  2015      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-21 21:00:00            21            2    21

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df.index, y=df.cnt);

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
# with lineplot
plt.figure(figsize=(10,6))
sns.lineplot(x=df.year_month, y=df.cnt, ci=0, estimator=sum)
plt.xticks(rotation=45);

# %%
# with lineplot
plt.figure(figsize=(10,6))
sns.lineplot(x=df.month, y=df.cnt);

# %%
# with pointplot
plt.figure(figsize=(10,6))
sns.pointplot(x=df.month, y=df.cnt);

# %%
# with barplot
plt.figure(figsize=(10,6))
sns.barplot(x=df.month, y=df.cnt);

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
# with lineplot (*whether it is a holiday or not*)
plt.figure(figsize=(12,6))
sns.lineplot(x=df.hour, y=df.cnt, hue=df.is_holiday);

# %%
# with lineplot (*You may want to see seasonal breakdowns*)
plt.figure(figsize=(12,6))
sns.lineplot(x=df.hour, y=df.cnt, hue=df.season);

# %%
# with pointplot
fig, ax=plt.subplots(4,1,figsize=(12,6))
sns.pointplot(x=df.hour, y=df.cnt, ax=ax[0])
sns.pointplot(x=df.hour, y=df.cnt, hue=df.is_holiday,ax=ax[1])
sns.pointplot(x=df.hour, y=df.cnt, hue=df.is_weekend,ax=ax[2] )
sns.pointplot(x=df.hour, y=df.cnt, hue=df.season,ax=ax[3] )
plt.tight_layout();

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
# with barplot
sns.barplot(x=df.day_of_week, y=df.cnt, hue=df.is_weekend);

# %%
# with pointplot
fig = plt.figure(figsize=(12,6))
fig=plt.subplot(2,1,1)
sns.pointplot(x=df.day_of_week, y=df.cnt)
fig = plt.subplot(2,1,2)
sns.pointplot(x=df.day_of_week, y=df.cnt, hue=df.season)
plt.tight_layout();

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
df.sample()
# Out:
#                       cnt    t1    t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-06-01 09:00:00  2077  13.5  13.5  53.0        23.0           2.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-06-01 09:00:00         0.0         0.0     1.0    2015-06  2015      6
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-06-01 09:00:00             1            0     9

# %%
df.groupby("day_of_month")[["cnt"]].mean().round().T
# Out:
# day_of_month      1       2       3       4       5       6       7       8   \
# cnt           1077.0  1088.0  1128.0  1144.0  1141.0  1211.0  1194.0  1223.0
#
# day_of_month      9       10  ...      22      23      24      25      26  \
# cnt           1261.0  1157.0  ...  1128.0  1174.0  1054.0  1191.0  1082.0
#
# day_of_month      27      28      29      30     31
# cnt           1131.0  1063.0  1080.0  1156.0  968.0
#
# [1 rows x 31 columns]

# %%
df.groupby("day_of_month")[["cnt"]].mean().round().T
sns.lineplot(x=df.day_of_month, y=df.cnt)
# Out:
# <AxesSubplot:xlabel='day_of_month', ylabel='cnt'>

# %%
#with lineplot
sns.lineplot(x=df.day_of_month, y=df.cnt)
# Out:
# day_of_month    1     2     3     4     5   ...    27    28    29    30   31
# cnt           1077  1088  1128  1144  1141  ...  1131  1063  1080  1156  968
#
# [1 rows x 31 columns]

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
x2 = df[df["is_holiday"]==1.0]
x2.season.value_counts()
# Out:
# 0.0    192
# 3.0    144
# 1.0     48
# Name: season, dtype: int64

# %%
# with barplot
sns.barplot(x="season", y="cnt", data=x2);

# %%
df.sample()
# Out:
#                      cnt    t1    t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-12-15 10:00:00  907  12.0  12.0  94.0        11.0           3.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-12-15 10:00:00         0.0         0.0     3.0    2015-12  2015     12
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-12-15 10:00:00            15            1    10

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
aa = df.is_weekend.value_counts()

# %%
p = list(aa.values)

# %%
# pie chart
plt.figure(figsize=(12,6), facecolor="w")
plt.pie(p ,labels=["weekday","weekend"], autopct="%.1f%%" );

# %%
def without_hue(plot, feature):
    total = len(feature)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 4.5 - 0.001
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y), size = 12)
        ax.annotate((p.get_height()), (p.get_x()+0.4, p.get_height()+0.9));
    plt.show()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="is_weekend", data=df)
without_hue(ax, df.is_weekend)

# %%
# with countplot
sns.countplot(df.is_weekend, data=df)

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
# with countplot
sns.countplot(df.weather_code, data=df);

# %%
# with catplot
sns.catplot(x = "weather_code", col="season", data=df, kind="count");

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
